# %%
# Gráfico del precio de cierre histórico
plt.figure(figsize=(14, 6))
plt.plot(btc["Close"], color="orange", linewidth=1.5)
plt.title("Precio histórico de Bitcoin (BTC-USD)", fontsize=16)
plt.xlabel("Fecha")
plt.ylabel("Precio en USD")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("../images/precio_historico.png")  # guarda la imagen
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Gráfico del precio de cierre histórico
# ----> 2 plt.figure(figsize=(14, 6))
#       3 plt.plot(btc["Close"], color="orange", linewidth=1.5)
#       4 plt.title("Precio histórico de Bitcoin (BTC-USD)", fontsize=16)
#       5 plt.xlabel("Fecha")
#
# NameError: name 'plt' is not defined
